# %%
# %load_ext autoreload
# %autoreload 2

import yeahml as yml

## prototype
from yeahml.dataset.tfd_handler.tfd_util import obtain_datasets, dataset_info

# %%
dataset_info("mnist_corrupted")
# Out:
# tfds.core.DatasetInfo(
#     name='mnist_corrupted',
#     version=0.0.1,
#     description='MNISTCorrupted is a dataset generated by adding 15 corruptions to the test
# images in the MNIST dataset. This dataset wraps the static, corrupted MNIST
# test images uploaded by the original authors
# ',
#     homepage='https://github.com/google-research/mnist-c',
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     total_num_examples=70000,
#     splits={
#         'test': 10000,
#         'train': 60000,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@article{mu2019mnist,
#       title={MNIST-C: A Robustness Benchmark for Computer Vision},
#       author={Mu, Norman and Gilmer, Justin},
#       journal={arXiv preprint arXiv:1906.02337},
#       year={2019}
#     }""",
#     redistribution_info=,
# )

# %%
train_set, valid_set, test_set = obtain_datasets(dataset_name="fashion_mnist", splits=[75,15,10])

# %%
example = "./examples/mnist/main_config.yaml"
config_dict = yml.create_configs(example)

# %%
model = yml.build_model(config_dict)
# Out:
# build_logger: INFO     -> START building graph
# build_logger: INFO     -> START building hidden block
# graph_logger: INFO     | conv_1          | no_shape
# graph_logger: INFO     | conv_2          | no_shape
# graph_logger: INFO     | dropout_1       | no_shape
# graph_logger: INFO     | pool_1          | no_shape
# graph_logger: INFO     | flatten_1       | no_shape
# graph_logger: INFO     | dense_1         | no_shape
# graph_logger: INFO     | dense_2_output  | no_shape
# build_logger: INFO     [END] building hidden block
# build_logger: INFO     information json file created

# %%
train_dict = yml.train_model(model, config_dict, (train_set, valid_set))
# Out:
# train_logger: INFO     -> START training graph
# train_logger: INFO     start creating train_dict
# train_logger: INFO     [END] creating train_dict

# %%
print(train_dict)
# Out:
# {'train_losses': [5.2148876, 0.97517395, 0.8133713], 'val_losses': [0.6497427, 0.5479164, 0.52609813], 'epochs': [0, 1, 2], 'meansquarederror': 0.022325985, 'val_meansquarederror': 0.02387536, 'topkcategoricalaccuracy': 0.93790907, 'val_topkcategoricalaccuracy': 0.9202, 'categoricalaccuracy': 0.84705454, 'val_categoricalaccuracy': 0.8316}

# %%
eval_dict = yml.eval_model(
    model,
    config_dict,
    dataset=test_set
)
print(eval_dict)
# Out:
# eval_logger : INFO     params loaded from examples/mnist/trial_01/model_a/save/params/run_2019_12_22-20_36_07/best_params.h5
# eval_logger : INFO     -> START evaluating model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3437137b86da> in <module>
#       2     model,
#       3     config_dict,
# ----> 4     dataset=test_set
#       5 )
#       6 print(eval_dict)
#
# ~/dev/github/YeahML/yeahml/evaluate/eval_model.py in eval_model(model, config_dict, dataset, weights_path)
#     110     logger.info("-> START evaluating model")
#     111     for step, (x_batch, y_batch) in enumerate(eval_ds):
# --> 112         eval_step(model, x_batch, y_batch, loss_object, avg_eval_loss, eval_metric_fns)
#     113     logger.info("[END] evaluating model")
#     114
#
# ...
